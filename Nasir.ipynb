# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **OMIWOLE NASIR OLAYIWOLA**
# Machine Learning Scientist and AI Engineer

# %% [markdown]
# *I am interested in Data Science, because i want to be able to make deductions from data by making very good insights and deductions*

# %% [markdown]
# ### Addition of two different numbers

# %%
50 + 75
# Out:
# 125

# %% [markdown]
# ![download%20%281%29.jfif](attachment:download%20%281%29.jfif)
# >IBM is a great course
# ***This is great
